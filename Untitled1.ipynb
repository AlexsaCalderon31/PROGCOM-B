# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexsaCalderon31/PROGCOM-B/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LISTAS
# Es un tipo de dato que permite almacenar infinita cantidad de datos en un espacio especifico llamado index.
# las listas **SON MUTABLES**
#
#
# ```
# # NOMBRE_LISTA=[]
# ```

# %%
total_personas=5
constructor=[]
for i in range(total_personas):
  exp=int(input(f"ingrese la experiencia del constructor {i}:"))
  constructor.append(exp)

# %%
#sum: suma todos los elementos de la lista
#len: cuenta todos los elemntos de la lista
promedio=sum(constructor)/len(constructor)
promedio

# %%
for i in range(total_personas):
  if constructor[i]>: print(f"El constructor {i} tiene mas expe")
