# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexsaCalderon31/PROGCOM-B/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DICCIONARIO
# Un DICCIONARIO ES UNA COLECCION DE ELEMENTOS DONDE CADA UNO KEY O LLAVES Y ASOCIA TIENE O VALE UN VALOR.
# Propiedades:
#
#
# *   Dinamicos: pueden crecer y añadir elemtos.
# *   Son indexados desde las llaves
# *   Pueden ser anidados
#
# Sintaxis
# ```
# diccionario={}
#
# diccionario={llave:valor,
# llaves2:valor2;....,
# llavem:valorn}
# ```

# %%
pedido={1:["hamburguesa","pizza","perro","gaseosa","pola","agua"],
        2:["sushi","spaguetti","gaseosa","jugo"],
        3:["ensalada","agua"]}

# %%
traductores={"nombres":["Ana","Valerie","Roxane","Julian","Mayra"],
             "notas":[0.1,5,2,4.9,4.9]}

# %%
print(pedido)
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua'], 2: ['sushi', 'spaguetti', 'gaseosa', 'jugo'], 3: ['ensalada', 'agua']}

# %%
pedido
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua'],
#  2: ['sushi', 'spaguetti', 'gaseosa', 'jugo'],
#  3: ['ensalada', 'agua']}

# %%
#Yo quiero saber, qué pidió la mesa 1
pedido[1]

# %%
if "perro" in pedido[1]:
  print("si pidieron perro")
else:
  print("No pidieron carro")

# %%
constructores={"nombres":["Ana","Valerie","Roxane","Julian","Mayre"],
                          "notas":[0.1,5,2,4.9,4.9]}

# %%
pedido.get(1)

# %%
print(constructores.get("notas"))
# Out:
# [0.1, 5, 2, 4.9, 4.9]

# %%
for nombre,notas in constructores.items():
  promedio = sum(notas) / len(notas)
  if promedio <= 7.0:
    print("perdió")
  else:
    print("pasó")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_674/4197388148.py in <cell line: 0>()
#       1 for nombre,notas in constructores.items():
# ----> 2   promedio = sum(notas) / len(notas)
#       3   if promedio <= 7.0:
#       4     print("perdio")
#       5   else:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
